# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import warnings
warnings.filterwarnings('ignore')


# Connect to the SQL database
conn = sqlite3.connect('/Users/habeeb/Downloads/Accident.db')

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('/Users/habeeb/Downloads/Accident.db')

# Get a cursor
cursor = conn.cursor()

# Query to fetch all table names in the database
query = "SELECT name FROM sqlite_master WHERE type='table';"

# Execute the query
cursor.execute(query)

# Fetch all table names
table_names = cursor.fetchall()

# Print the table names
for name in table_names:
    print(name[0])

# Close the cursor and connection
# Out:
# accident
# casualty
# vehicle
# lsoa

# %%
# Query to retrieve accident data and timestamp
query = """
SELECT *
FROM Accident
WHERE accident_year =2020 
"""
accident=pd.read_sql(query, conn)

# %%
accident.columns
# Out:
# Index(['accident_index', 'accident_year', 'accident_reference',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'latitude', 'police_force', 'accident_severity', 'number_of_vehicles',
#        'number_of_casualties', 'date', 'day_of_week', 'time',
#        'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag', 'lsoa_of_accident_location'],
#       dtype='object')

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91199 entries, 0 to 91198
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   accident_index                               91199 non-null  object
#  1   accident_year                                91199 non-null  int64
#  2   accident_reference                           91199 non-null  object
#  3   location_easting_osgr                        91185 non-null  float64
#  4   location_northing_osgr                       91185 non-null  float64
#  5   longitude                                    91185 non-null  float64
#  6   latitude                                     91185 non-null  float64
#  7   police_force                                 91199 non-null  int64
#  8   accident_severity                            91199 non-null  int64
#  9   number_of_vehicles                           91199 non-null  int64
#  10  number_of_casualties                         91199 non-null  int64
#  11  date                                         91199 non-null  object
#  12  day_of_week                                  91199 non-null  int64
#  13  time                                         91199 non-null  object
#  14  local_authority_district                     91199 non-null  int64
#  15  local_authority_ons_district                 91199 non-null  object
#  16  local_authority_highway                      91199 non-null  object
#  17  first_road_class                             91199 non-null  int64
#  18  first_road_number                            91199 non-null  int64
#  19  road_type                                    91199 non-null  int64
#  20  speed_limit                                  91199 non-null  int64
#  21  junction_detail                              91199 non-null  int64
#  22  junction_control                             91199 non-null  int64
#  23  second_road_class                            91199 non-null  int64
#  24  second_road_number                           91199 non-null  int64
#  25  pedestrian_crossing_human_control            91199 non-null  int64
#  26  pedestrian_crossing_physical_facilities      91199 non-null  int64
#  27  light_conditions                             91199 non-null  int64
#  28  weather_conditions                           91199 non-null  int64
#  29  road_surface_conditions                      91199 non-null  int64
#  30  special_conditions_at_site                   91199 non-null  int64
#  31  carriageway_hazards                          91199 non-null  int64
#  32  urban_or_rural_area                          91199 non-null  int64
#  33  did_police_officer_attend_scene_of_accident  91199 non-null  int64
#  34  trunk_road_flag                              91199 non-null  int64
#  35  lsoa_of_accident_location                    91199 non-null  object
# dtypes: float64(4), int64(25), object(7)
# memory usage: 25.0+ MB

# %%
accident['police_force'].
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: police_force, dtype: int64

# %%
accident['lsoa_of_accident_location']
# Out:
# 0        E01004576
# 1        E01003034
# 2        E01004726
# 3        E01003617
# 4        E01004763
#            ...
# 91194           -1
# 91195           -1
# 91196           -1
# 91197           -1
# 91198           -1
# Name: lsoa_of_accident_location, Length: 91199, dtype: object

# %% [markdown]
# ## Q1.

# %%
# Combine date and time columns into a single datetime column
df=accident.copy()
df['time'] = pd.to_datetime(df['time'])

# Extract hour from the datetime
df['HourOfDay'] = df['time'].dt.hour

# Mapping day of the week to actual names
day_of_week_map = {
    0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednessday',
    4: 'Thursday', 5: 'Friday', 6: 'Saturday'
}
df['DayOfWeek'] = df['day_of_week'].map(day_of_week_map)

# Group by day of the week, hour, and count accidents
accidents_by_day_hour = df.groupby(['DayOfWeek', 'HourOfDay']).size().reset_index(name='AccidentCount')

# Create a line plot to show trends of accidents throughout the day
plt.figure(figsize=(12, 8))
sns.lineplot(data=accidents_by_day_hour, x='HourOfDay', y='AccidentCount', hue='DayOfWeek', palette='Set2')
plt.title('Accident Trends by Day of Week and Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Accident Count')
plt.xticks(range(24))
plt.legend(title='Day of Week')
plt.show()

# %% [markdown]
# ## Q2

# %%
Vehicle_Query='''
SELECT acc.accident_index, acc.accident_year, acc.time,acc.day_of_week, acc.date, veh.vehicle_index, veh.vehicle_type
FROM accident AS acc
JOIN vehicle AS veh ON acc.accident_index = veh.accident_index
WHERE acc.accident_year = 2020 AND veh.vehicle_type IN (3,4,5)
'''
Specific_Motorcycle = pd.read_sql(Vehicle_Query,conn)
Specific_Motorcycle
# Out:
#       accident_index  accident_year   time  day_of_week        date  \
# 0      2020010228020           2020  03:25            4  01/01/2020
# 1      2020010228086           2020  14:00            4  01/01/2020
# 2      2020010228097           2020  14:37            4  01/01/2020
# 3      2020010228148           2020  19:05            4  01/01/2020
# 4      2020010228207           2020  14:29            4  01/01/2020
# ...              ...            ...    ...          ...         ...
# 12993  2020991010130           2020  16:30            5  24/12/2020
# 12994  2020991011809           2020  17:30            4  16/12/2020
# 12995  2020991012311           2020  17:55            2  28/12/2020
# 12996  2020991012353           2020  15:45            5  06/08/2020
# 12997  2020991030297           2020  12:42            4  15/04/2020
#
#        vehicle_index  vehicle_type
# 0             681728             3
# 1             681749             3
# 2             681752             3
# 3             681774             3
# 4             681793             3
# ...              ...           ...
# 12993         848911             3
# 12994         849008             3
# 12995         849017             3
# 12996         849020             4
# 12997         849087             5
#
# [12998 rows x 7 columns]

# %%
df=Specific_Motorcycle.copy()

# %%
df['time'] = pd.to_datetime(df['time'])

df['HourOfDay'] = df['time'].dt.hour


# Mapping day of the week to actual names
day_of_week_map = {
    0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednessday',
    4: 'Thursday', 5: 'Friday', 6: 'Saturday'
}
df['DayOfWeek'] = df['day_of_week'].map(day_of_week_map)

# Group by day of the week, hour, and count accidents
accidents_by_day_hour = df.groupby(['DayOfWeek', 'HourOfDay']).size().reset_index(name='AccidentCount')

# Create a line plot to show trends of accidents throughout the day
plt.figure(figsize=(12, 8))
sns.lineplot(data=accidents_by_day_hour, x='HourOfDay', y='AccidentCount', hue='DayOfWeek', palette='Set2')
plt.title('Motorcyles >50cc & >=500cc')
plt.xlabel('Hour of Day')
plt.ylabel('Accident Count')
plt.xticks(range(24))
plt.legend(title='Day of Week')
plt.show()

# %% [markdown]
# ## Q3

# %%
Casualty_Query = ''' 
SELECT acc.accident_index, acc.accident_year, acc.time, acc.day_of_week, cas.casualty_index, cas.casualty_class
FROM accident AS acc
JOIN casualty AS cas ON acc.accident_index = cas.accident_index
WHERE acc.accident_year = 2020 AND cas.casualty_class = 3
'''
Ped_inv = pd.read_sql(Casualty_Query,conn)
Ped_inv
# Out:
#       accident_index  accident_year   time  day_of_week  casualty_index  \
# 0      2020010219808           2020  09:00            3          484748
# 1      2020010220496           2020  13:55            2          484749
# 2      2020010220496           2020  13:55            2          484750
# 3      2020010228005           2020  01:25            4          484751
# 4      2020010228006           2020  01:50            4          484752
# ...              ...            ...    ...          ...             ...
# 14745  2020991023621           2020  10:30            3          600321
# 14746  2020991023880           2020  17:00            2          600322
# 14747  2020991024526           2020  12:00            3          600326
# 14748  2020991029573           2020  15:05            6          600328
# 14749  2020991032575           2020  13:50            3          600331
#
#        casualty_class
# 0                   3
# 1                   3
# 2                   3
# 3                   3
# 4                   3
# ...               ...
# 14745               3
# 14746               3
# 14747               3
# 14748               3
# 14749               3
#
# [14750 rows x 6 columns]

# %%
df=Ped_inv.copy()
df['time'] = pd.to_datetime(df['time'])

df['HourOfDay'] = df['time'].dt.hour


# Mapping day of the week to actual names
day_of_week_map = {
    0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednessday',
    4: 'Thursday', 5: 'Friday', 6: 'Saturday'
}
df['DayOfWeek'] = df['day_of_week'].map(day_of_week_map)

# Group by day of the week, hour, and count accidents
accidents_by_day_hour = df.groupby(['DayOfWeek', 'HourOfDay']).size().reset_index(name='AccidentCount')

# Create a line plot to show trends of accidents throughout the day
plt.figure(figsize=(12, 8))
sns.lineplot(data=accidents_by_day_hour, x='HourOfDay', y='AccidentCount', hue='DayOfWeek', palette='Set2')
plt.title('Pedestrian involved in accidents')
plt.xlabel('Hour of Day')
plt.ylabel('Accident Count')
plt.xticks(range(24))
plt.legend(title='Day of Week')
plt.show()

# %% [markdown]
# ## Q4

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import sqlite3

# Load data from your database
conn = sqlite3.connect('/Users/habeeb/Downloads/Accident.db')
query = """
SELECT speed_limit,road_surface_conditions, weather_conditions, accident_severity
FROM accident
"""
df = pd.read_sql(query, conn)

# %%
df.head()
# Out:
#    speed_limit  road_surface_conditions  weather_conditions  accident_severity
# 0           30                        1                   1                  1
# 1           30                        2                   1                  3
# 2           30                        1                   1                  3
# 3           30                        2                   2                  3
# 4           20                        2                   1                  2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461352 entries, 0 to 461351
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   speed_limit              461352 non-null  int64
#  1   road_surface_conditions  461352 non-null  int64
#  2   weather_conditions       461352 non-null  int64
#  3   accident_severity        461352 non-null  int64
# dtypes: int64(4)
# memory usage: 14.1 MB

# %%
# Convert categorical variables into numerical using one-hot encoding
df_encoded = pd.get_dummies(df, columns=['speed_limit','road_surface_conditions', 'weather_conditions'])

# Convert one-hot encoded columns to boolean values
for column in df_encoded.columns:
    df_encoded[column] = df_encoded[column].astype(bool)

# Prepare transaction dataset
transactions = df_encoded.drop(['accident_severity'], axis=1)

# Apply Apriori algorithm
frequent_itemsets = apriori(transactions, min_support=0.2, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print association rules
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Association Rules:
#                                           antecedents  \
# 0                                    (speed_limit_30)
# 1                         (road_surface_conditions_1)
# 2                              (weather_conditions_1)
# 3                                    (speed_limit_30)
# 4                              (weather_conditions_1)
# 5                         (road_surface_conditions_1)
# 6              (weather_conditions_1, speed_limit_30)
# 7   (weather_conditions_1, road_surface_conditions_1)
# 8         (speed_limit_30, road_surface_conditions_1)
# 9                              (weather_conditions_1)
# 10                                   (speed_limit_30)
# 11                        (road_surface_conditions_1)
#
#                                           consequents   support  confidence  \
# 0                         (road_surface_conditions_1)  0.435284    0.731280
# 1                                    (speed_limit_30)  0.435284    0.611893
# 2                                    (speed_limit_30)  0.476458    0.598990
# 3                              (weather_conditions_1)  0.476458    0.800454
# 4                         (road_surface_conditions_1)  0.673037    0.846123
# 5                              (weather_conditions_1)  0.673037    0.946111
# 6                         (road_surface_conditions_1)  0.410504    0.861575
# 7                                    (speed_limit_30)  0.410504    0.609928
# 8                              (weather_conditions_1)  0.410504    0.943073
# 9         (speed_limit_30, road_surface_conditions_1)  0.410504    0.516075
# 10  (weather_conditions_1, road_surface_conditions_1)  0.410504    0.689651
# 11             (weather_conditions_1, speed_limit_30)  0.410504    0.577060
#
#         lift
# 0   1.027985
# 1   1.027985
# 2   1.006308
# 3   1.006308
# 4   1.189424
# 5   1.189424
# 6   1.211144
# 7   1.024684
# 8   1.185605
# 9   1.185605
# 10  1.024684
# 11  1.211144

# %%
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.595235                                   (speed_limit_30)
# 1   0.125787                                   (speed_limit_60)
# 2   0.711372                        (road_surface_conditions_1)
# 3   0.258540                        (road_surface_conditions_2)
# 4   0.795436                             (weather_conditions_1)
# 5   0.116974                             (weather_conditions_2)
# 6   0.435284        (speed_limit_30, road_surface_conditions_1)
# 7   0.143311        (speed_limit_30, road_surface_conditions_2)
# 8   0.476458             (weather_conditions_1, speed_limit_30)
# 9   0.673037  (weather_conditions_1, road_surface_conditions_1)
# 10  0.111915  (weather_conditions_1, road_surface_conditions_2)
# 11  0.113113  (weather_conditions_2, road_surface_conditions_2)
# 12  0.410504  (weather_conditions_1, speed_limit_30, road_su...

# %%
rules
# Out:
#                                           antecedents  \
# 0                                    (speed_limit_30)
# 1                         (road_surface_conditions_1)
# 2                              (weather_conditions_1)
# 3                                    (speed_limit_30)
# 4                              (weather_conditions_1)
# 5                         (road_surface_conditions_1)
# 6              (weather_conditions_1, speed_limit_30)
# 7   (weather_conditions_1, road_surface_conditions_1)
# 8         (speed_limit_30, road_surface_conditions_1)
# 9                              (weather_conditions_1)
# 10                                   (speed_limit_30)
# 11                        (road_surface_conditions_1)
#
#                                           consequents  antecedent support  \
# 0                         (road_surface_conditions_1)            0.595235
# 1                                    (speed_limit_30)            0.711372
# 2                                    (speed_limit_30)            0.795436
# 3                              (weather_conditions_1)            0.595235
# 4                         (road_surface_conditions_1)            0.795436
# 5                              (weather_conditions_1)            0.711372
# 6                         (road_surface_conditions_1)            0.476458
# 7                                    (speed_limit_30)            0.673037
# 8                              (weather_conditions_1)            0.435284
# 9         (speed_limit_30, road_surface_conditions_1)            0.795436
# 10  (weather_conditions_1, road_surface_conditions_1)            0.595235
# 11             (weather_conditions_1, speed_limit_30)            0.711372
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.711372  0.435284    0.731280  1.027985  0.011850    1.074084
# 1             0.595235  0.435284    0.611893  1.027985  0.011850    1.042920
# 2             0.595235  0.476458    0.598990  1.006308  0.002987    1.009363
# 3             0.795436  0.476458    0.800454  1.006308  0.002987    1.025146
# 4             0.711372  0.673037    0.846123  1.189424  0.107186    1.875710
# 5             0.795436  0.673037    0.946111  1.189424  0.107186    3.796023
# 6             0.711372  0.410504    0.861575  1.211144  0.071565    2.085077
# 7             0.595235  0.410504    0.609928  1.024684  0.009889    1.037667
# 8             0.795436  0.410504    0.943073  1.185605  0.064264    3.593451
# 9             0.435284  0.410504    0.516075  1.185605  0.064264    1.166949
# 10            0.673037  0.410504    0.689651  1.024684  0.009889    1.053531
# 11            0.476458  0.410504    0.577060  1.211144  0.071565    1.237862
#
#     zhangs_metric
# 0        0.067257
# 1        0.094319
# 2        0.030644
# 3        0.015487
# 4        0.778520
# 5        0.551774
# 6        0.332991
# 7        0.073677
# 8        0.277217
# 9        0.765281
# 10       0.059515
# 11       0.604012

# %% [markdown]
# ## Q5.

# %%
# Query to retrieve accident data and timestamp
query = """
SELECT acc.accident_year, acc.speed_limit,acc.police_force, acc.accident_severity, acc.latitude, acc.longitude, l.lsoa01cd, l.lsoa01nm,l.shape__area,l.shape__length
FROM accident AS acc
JOIN lsoa AS l ON acc.lsoa_of_accident_location = l.lsoa01cd
WHERE l.lsoa01nm like '%Kingston upon Hull%' and acc.accident_year =2020
"""

ls=pd.read_sql(query, conn)

# %%
ls.head()
# Out:
#    accident_year  speed_limit  police_force  accident_severity   latitude  \
# 0           2020           30            16                  3  53.744936
# 1           2020           30            16                  2  53.791630
# 2           2020           30            16                  3  53.767805
# 3           2020           30            16                  3  53.750410
# 4           2020           30            16                  3  53.777540
#
#    longitude   lsoa01cd                 lsoa01nm   shape__area  shape__length
# 0  -0.393424  E01012777  Kingston upon Hull 028E  3.567509e+05    3963.099631
# 1  -0.324858  E01012788  Kingston upon Hull 002E  4.380009e+05    4731.122554
# 2  -0.327733  E01012817  Kingston upon Hull 016D  1.798393e+06    7836.548217
# 3  -0.309102  E01012810  Kingston upon Hull 026D  9.637633e+05    7120.401224
# 4  -0.335481  E01012817  Kingston upon Hull 016D  1.798393e+06    7836.548217

# %%
# Perform any necessary data preprocessing (e.g., normalization)
df=ls.copy()
# Apply K-means clustering
num_clusters = 2
# Choose an appropriate number of clusters
kmeans = KMeans(n_clusters=num_clusters)
df['cluster'] = kmeans.fit_predict(df[['latitude','longitude']])

# Visualize clusters
plt.scatter(df['longitude'], df['latitude'], c=df['cluster'], cmap='rainbow')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Accident Clusters in the Region')
plt.show()

# %% [markdown]
# ## Q6

# %%
data=accident.dropna()
# Select numerical features for outlier detection
numerical_features = data.select_dtypes(include=[np.number])

# Initialize Isolation Forest model
iso_forest = IsolationForest(contamination=0.01)  # Adjust contamination based on your data

# Fit the model and predict outliers
outlier_preds = iso_forest.fit_predict(numerical_features)

# Add outlier predictions to the original dataset
data['outlier'] = outlier_preds

# Visualize outliers
plt.scatter(data['speed_limit'], data['day_of_week'], c=data['outlier'], cmap='coolwarm')
plt.xlabel('speed_limit')
plt.ylabel('day_of_week')
plt.title('Outlier Detection using Isolation Forest')
plt.show()

# Print statistics about outliers
print("Number of outliers:", (outlier_preds == -1).sum())
# Out:
# Number of outliers: 912

# %%
# Create boxplots for all columns
plt.figure(figsize=(10, 6))
data.boxplot()
plt.title('Boxplots of Columns')
plt.xticks(rotation=45)
plt.show()

# %%
vehicle_data = pd.read_sql_query("SELECT age_of_driver, age_of_vehicle FROM vehicle", conn)

# %%
# Create boxplots for all columns
plt.figure(figsize=(10, 6))
vehicle_data.boxplot()
plt.title('Boxplots of Columns')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Q7

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (3.0.0rc9)
# Requirement already satisfied: markupsafe>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: kaleido>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: pyod>=0.9.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.0.7)
# Requirement already satisfied: numba>=0.55.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.56.4)
# Requirement already satisfied: yellowbrick>=1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.5)
# Requirement already satisfied: lightgbm>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: requests>=2.27.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.28.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (4.12.0)
# Requirement already satisfied: sktime>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.16.0)
# Requirement already satisfied: deprecation>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (5.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (3.5.3)
# Requirement already satisfied: scikit-learn>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: scipy<2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.5.4)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: ipython>=5.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (7.22.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: plotly-resampler>=0.7.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.8.4rc1)
# Requirement already satisfied: category-encoders>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.5.0)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: tbats>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.1.2)
# Requirement already satisfied: schemdraw>=0.14 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: tqdm>=4.62.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: psutil>=5.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (5.9.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: jinja2>=1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: plotly>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pycaret) (5.10.0)
# Requirement already satisfied: patsy>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.8.1)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (49.2.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.18)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.18.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (5.5.3)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: wheel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (9.1.1)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (3.2.0)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.7.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2021.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret) (8.1.0)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.4.2)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.8.1)
# Requirement already satisfied: Flask-Cors<4.0.0,>=3.0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.0.10)
# Requirement already satisfied: trace-updater>=0.0.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.0.9)
# Requirement already satisfied: Werkzeug<=2.1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.1.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.8.6)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.0a11)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.4)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyod>=0.9.8->pycaret) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2020.12.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.1.0)
# Requirement already satisfied: deprecated>=1.2.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sktime>=0.15.0->pycaret) (1.2.13)
# Requirement already satisfied: dash-table==5.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime>=0.15.0->pycaret) (1.14.1)
# Requirement already satisfied: jupyter-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->pycaret) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->pycaret) (20.3.0)
# Requirement already satisfied: ansi2html in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.9.0rc1)
# Requirement already satisfied: nest-asyncio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.5.1)
# Requirement already satisfied: retrying in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.3.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: itsdangerous>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (8.1.3)
# Requirement already satisfied: pyzmq>=13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (22.0.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip3.9 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(accident, target = 'accident_severity', session_id = 123)
# Out:
# <style type="text/css">
# #T_0c20d_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0c20d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c20d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0c20d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c20d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c20d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0c20d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c20d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0c20d_row1_col1" class="data row1 col1" >accident_severity</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c20d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0c20d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c20d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_0c20d_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c20d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_0c20d_row4_col1" class="data row4 col1" >(91185, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c20d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_0c20d_row5_col1" class="data row5 col1" >(91185, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c20d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_0c20d_row6_col1" class="data row6 col1" >(63829, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c20d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_0c20d_row7_col1" class="data row7 col1" >(27356, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c20d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0c20d_row8_col1" class="data row8 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c20d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_0c20d_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0c20d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_0c20d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0c20d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_0c20d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0c20d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_0c20d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0c20d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_0c20d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0c20d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_0c20d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0c20d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_0c20d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0c20d_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_0c20d_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0c20d_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_0c20d_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0c20d_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_0c20d_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0c20d_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_0c20d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0c20d_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_0c20d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0c20d_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_0c20d_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0c20d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0c20d_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_0c20d_row22_col1" class="data row22 col1" >bda8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import ClassificationExperiment and init the class
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
exp

# %%
# init setup on exp
exp.setup(accident, target = 'accident_severity', session_id = 123)
# Out:
# <style type="text/css">
# #T_34ff8_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_34ff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ff8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_34ff8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ff8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34ff8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_34ff8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34ff8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_34ff8_row1_col1" class="data row1 col1" >accident_severity</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34ff8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_34ff8_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34ff8_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_34ff8_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34ff8_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_34ff8_row4_col1" class="data row4 col1" >(91185, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34ff8_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_34ff8_row5_col1" class="data row5 col1" >(91185, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34ff8_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_34ff8_row6_col1" class="data row6 col1" >(63829, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34ff8_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_34ff8_row7_col1" class="data row7 col1" >(27356, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34ff8_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_34ff8_row8_col1" class="data row8 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34ff8_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_34ff8_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_34ff8_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_34ff8_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_34ff8_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_34ff8_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_34ff8_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_34ff8_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_34ff8_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_34ff8_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_34ff8_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_34ff8_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_34ff8_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_34ff8_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_34ff8_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_34ff8_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_34ff8_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_34ff8_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_34ff8_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_34ff8_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_34ff8_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_34ff8_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_34ff8_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_34ff8_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_34ff8_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_34ff8_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_34ff8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_34ff8_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_34ff8_row22_col1" class="data row22 col1" >3bba</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_974ed th {
#   text-align: left;
# }
# #T_974ed_row0_col0, #T_974ed_row0_col2, #T_974ed_row0_col5, #T_974ed_row0_col6, #T_974ed_row0_col7, #T_974ed_row1_col0, #T_974ed_row1_col1, #T_974ed_row1_col2, #T_974ed_row1_col3, #T_974ed_row1_col4, #T_974ed_row1_col5, #T_974ed_row1_col6, #T_974ed_row1_col7, #T_974ed_row2_col0, #T_974ed_row2_col1, #T_974ed_row2_col2, #T_974ed_row2_col3, #T_974ed_row2_col4, #T_974ed_row2_col5, #T_974ed_row2_col6, #T_974ed_row2_col7, #T_974ed_row3_col0, #T_974ed_row3_col1, #T_974ed_row3_col2, #T_974ed_row3_col3, #T_974ed_row3_col4, #T_974ed_row3_col5, #T_974ed_row3_col6, #T_974ed_row3_col7, #T_974ed_row4_col0, #T_974ed_row4_col1, #T_974ed_row4_col2, #T_974ed_row4_col3, #T_974ed_row4_col4, #T_974ed_row4_col5, #T_974ed_row4_col6, #T_974ed_row4_col7, #T_974ed_row5_col0, #T_974ed_row5_col1, #T_974ed_row5_col2, #T_974ed_row5_col3, #T_974ed_row5_col4, #T_974ed_row5_col5, #T_974ed_row5_col6, #T_974ed_row5_col7, #T_974ed_row6_col0, #T_974ed_row6_col1, #T_974ed_row6_col3, #T_974ed_row6_col4, #T_974ed_row7_col0, #T_974ed_row7_col1, #T_974ed_row7_col2, #T_974ed_row7_col3, #T_974ed_row7_col4, #T_974ed_row7_col5, #T_974ed_row7_col6, #T_974ed_row7_col7, #T_974ed_row8_col0, #T_974ed_row8_col1, #T_974ed_row8_col2, #T_974ed_row8_col3, #T_974ed_row8_col4, #T_974ed_row8_col5, #T_974ed_row8_col6, #T_974ed_row8_col7, #T_974ed_row9_col0, #T_974ed_row9_col1, #T_974ed_row9_col2, #T_974ed_row9_col3, #T_974ed_row9_col4, #T_974ed_row9_col5, #T_974ed_row9_col6, #T_974ed_row9_col7, #T_974ed_row10_col0, #T_974ed_row10_col1, #T_974ed_row10_col2, #T_974ed_row10_col3, #T_974ed_row10_col4, #T_974ed_row10_col5, #T_974ed_row10_col6, #T_974ed_row10_col7, #T_974ed_row11_col0, #T_974ed_row11_col1, #T_974ed_row11_col2, #T_974ed_row11_col3, #T_974ed_row11_col4, #T_974ed_row11_col5, #T_974ed_row11_col6, #T_974ed_row11_col7, #T_974ed_row12_col0, #T_974ed_row12_col1, #T_974ed_row12_col2, #T_974ed_row12_col3, #T_974ed_row12_col4, #T_974ed_row12_col5, #T_974ed_row12_col6, #T_974ed_row12_col7, #T_974ed_row13_col0, #T_974ed_row13_col1, #T_974ed_row13_col2, #T_974ed_row13_col3, #T_974ed_row13_col4, #T_974ed_row13_col5, #T_974ed_row13_col6, #T_974ed_row13_col7, #T_974ed_row14_col0, #T_974ed_row14_col1, #T_974ed_row14_col2, #T_974ed_row14_col3, #T_974ed_row14_col4, #T_974ed_row14_col5, #T_974ed_row14_col6, #T_974ed_row14_col7 {
#   text-align: left;
# }
# #T_974ed_row0_col1, #T_974ed_row0_col3, #T_974ed_row0_col4, #T_974ed_row6_col2, #T_974ed_row6_col5, #T_974ed_row6_col6, #T_974ed_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_974ed_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_974ed_row1_col8, #T_974ed_row2_col8, #T_974ed_row3_col8, #T_974ed_row4_col8, #T_974ed_row5_col8, #T_974ed_row6_col8, #T_974ed_row7_col8, #T_974ed_row8_col8, #T_974ed_row9_col8, #T_974ed_row10_col8, #T_974ed_row11_col8, #T_974ed_row12_col8, #T_974ed_row13_col8, #T_974ed_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_974ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_974ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_974ed_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_974ed_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_974ed_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_974ed_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_974ed_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_974ed_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_974ed_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_974ed_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_974ed_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_974ed_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_974ed_row0_col1" class="data row0 col1" >0.7842</td>
#       <td id="T_974ed_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_974ed_row0_col3" class="data row0 col3" >0.7842</td>
#       <td id="T_974ed_row0_col4" class="data row0 col4" >0.7146</td>
#       <td id="T_974ed_row0_col5" class="data row0 col5" >0.6958</td>
#       <td id="T_974ed_row0_col6" class="data row0 col6" >0.0231</td>
#       <td id="T_974ed_row0_col7" class="data row0 col7" >0.0706</td>
#       <td id="T_974ed_row0_col8" class="data row0 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_974ed_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_974ed_row1_col0" class="data row1 col0" >Dummy Classifier</td>
#       <td id="T_974ed_row1_col1" class="data row1 col1" >0.7835</td>
#       <td id="T_974ed_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_974ed_row1_col3" class="data row1 col3" >0.7835</td>
#       <td id="T_974ed_row1_col4" class="data row1 col4" >0.6138</td>
#       <td id="T_974ed_row1_col5" class="data row1 col5" >0.6883</td>
#       <td id="T_974ed_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_974ed_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_974ed_row1_col8" class="data row1 col8" >1.1070</td>
#     </tr>
#     <tr>
#       <th id="T_974ed_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_974ed_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_974ed_row2_col1" class="data row2 col1" >0.7834</td>
#       <td id="T_974ed_row2_col2" class="data row2 col2" >0.5722</td>
#       <td id="T_974ed_row2_col3" class="data row2 col3" >0.7834</td>
#       <td id="T_974ed_row2_col4" class="data row2 col4" >0.6541</td>
#       <td id="T_974ed_row2_col5" class="data row2 col5" >0.6884</td>
#       <td id="T_974ed_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_974ed_row2_col7" class="data row2 col7" >0.0011</td>
#       <td id="T_974ed_row2_col8" class="data row2 col8" >5.8760</td>
#     </tr>
#     <tr>
#       <th id="T_974ed_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_974ed_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_974ed_row3_col1" class="data row3 col1" >0.7823</td>
#       <td id="T_974ed_row3_col2" class="data row3 col2" >0.6247</td>
#       <td id="T_974ed_row3_col3" class="data row3 col3" >0.7823</td>
#       <td id="T_974ed_row3_col4" class="data row3 col4" >0.6999</td>
#       <td id="T_974ed_row3_col5" class="data row3 col5" >0.6948</td>
#       <td id="T_974ed_row3_col6" class="data row3 col6" >0.0204</td>
#       <td id="T_974ed_row3_col7" class="data row3 col7" >0.0543</td>
#       <td id="T_974ed_row3_col8" class="data row3 col8" >3.2960</td>
#     </tr>
#     <tr>
#       <th id="T_974ed_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_974ed_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_974ed_row4_col1" class="data row4 col1" >0.7809</td>
#       <td id="T_974ed_row4_col2" class="data row4 col2" >0.6523</td>
#       <td id="T_974ed_row4_col3" class="data row4 col3" >0.7809</td>
#       <td id="T_974ed_row4_col4" class="data row4 col4" >0.7026</td>
#       <td id="T_974ed_row4_col5" class="data row4 col5" >0.7008</td>
#       <td id="T_974ed_row4_col6" class="data row4 col6" >0.0379</td>
#       <td id="T_974ed_row4_col7" class="data row4 col7" >0.0752</td>
#       <td id="T_974ed_row4_col8" class="data row4 col8" >9.3690</td>
#     </tr>
#     <tr>
#       <th id="T_974ed_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_974ed_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_974ed_row5_col1" class="data row5 col1" >0.7766</td>
#       <td id="T_974ed_row5_col2" class="data row5 col2" >0.6044</td>
#       <td id="T_974ed_row5_col3" class="data row5 col3" >0.7766</td>
#       <td id="T_974ed_row5_col4" class="data row5 col4" >0.6741</td>
#       <td id="T_974ed_row5_col5" class="data row5 co

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
