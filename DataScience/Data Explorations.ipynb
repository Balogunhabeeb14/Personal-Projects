# %%
# Import the data
import pandas as pd
xls = pd.ExcelFile('DATA.xlsx',engine='openpyxl')

#print the names of each sheets in the excel file
xls.sheet_names
# Out:
# ['Raw', 'Coded']

# %%
#convert each and every excel sheet as dataframe and assign them same name as the worksheet's name
#sheet_names=sheet_names()

for name in xls.sheet_names:
    if name.isdigit():
        exec(f"Sheet_name{name}=pd.read_excel('PhD Data.xlsx', sheet_name='{name}',engine='openpyxl')")

    else:
        exec(f"{name}=pd.read_excel('PhD Data.xlsx', sheet_name='{name}',engine='openpyxl')")

# %%
Raw.head()
# Out:
#   Full Participation   what was done                       Role  \
# 0                yes  Deconstruction  Civil/Structural engineer
# 1                yes      Renovation                 Supervisor
# 2                yes  Deconstruction       construction manager
# 3                 no             NaN                        NaN
# 4                 no             NaN                        NaN
#
#                                      why deconstruct Project Location  \
# 0  Much of the components/materials are reusable ...               UK
# 1  Much of the components/materials are reusable ...          Nigeria
# 2  Much of the components/materials are reusable ...          Nigeria
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#    Building type construction method Building Age      Floors      Rooms  ...  \
# ...

# %%
Raw.describe()
# Out:
#        Full Participation what was done       Role  \
# count                  98            47         41
# unique                  2             4         12
# top                   yes    Renovation  Architect
# freq                   53            19          9
#
#                                           why deconstruct Project Location  \
# count                                                  42               41
# unique                                                 14                9
# top     Much of the components/materials are reusable ...          Nigeria
# freq                                                   20               18
#
#        Building type construction method Building Age      Floors      Rooms  \
# count             42                  41           42          42         42
# unique             5                   5            5           5          4
# top      Residential         Traditional      0-20yrs  1-3 floors  3-5 rooms
# ...

# %%
Raw.columns
# Out:
# Index(['Full Participation', 'what was done', 'Role', 'why deconstruct',
#        'Project Location', 'Building type', 'construction method',
#        'Building Age', 'Floors', 'Rooms', 'Area of Floor', 'Structure type',
#        'Ease of deconstruction', 'Deconstructability score', 'Project Barrier',
#        'Responsible for Barrier', 'Policies influence Project', 'Policy Kind',
#        'Public attitude influence Project', 'Kind of public attitude',
#        'Need for transportation', 'Labour Cost', 'Landfill cost',
#        'Permit cost', 'Toxic Handler cost', 'Standard Qty Assesments',
#        'Standard Grading Assessments', 'Market for Recoveries',
#        'Financial Aids', 'Storage cost', 'Materials Recovered',
#        'Banned Material', 'Damages', 'Inventory information',
#        'Planning information', 'Composite Material', 'Connections accessible',
#        'Separatability of Elements', 'Regulations influence project',
# ...

# %%
# iterating the columns
for col in Raw.columns:
    print(col)
# Out:
# Full Participation
# what was done
# Role
# why deconstruct
# Project Location
# Building type
# construction method
# Building Age
# Floors
# Rooms
# Area of Floor
# Structure type
# Ease of deconstruction
# Deconstructability score
# Project Barrier
# Responsible for Barrier
# Policies influence Project
# Policy Kind
# Public attitude influence Project
# Kind of public attitude
# Need for transportation
# Labour Cost
# Landfill cost
# Permit cost
# Toxic Handler cost
# Standard Qty Assesments
# Standard Grading Assessments
# Market for Recoveries
# Financial Aids
# Storage cost
# Materials Recovered
# Banned Material
# Damages
# Inventory information
# Planning information
# Composite Material
# Connections accessible
# Separatability of Elements
# Regulations influence project
# Example regulation
# project was done in
# Sorting & processing time
# Assessment time
# Project time
# Drivers that influence schedule
# Other useful insight

# %%
for col in Raw:
  print(Raw[col].unique())
# Out:
# ['yes' 'no']
# ['Deconstruction' 'Renovation' nan 'Demolition' 'Abandon/Do nothing']
# ['Civil/Structural engineer' 'Supervisor' 'construction manager' nan
#  'Labourer' 'Architect' 'Surveyor' 'Client' 'Decision maker/owner'
#  'HSE officer' 'Builder' 'Safety Officer' 'Monitoring Officer']
# ['Much of the components/materials are reusable and recyclable,Much of the wastes can be diverted,More jobs can be created,Generation of revenues'
#  'Much of the components/materials are reusable and recyclable' nan
#  'More jobs can be created' 'Generation of revenues'
#  'Much of the components/materials are reusable and recyclable,Generation of revenues'
#  'Renovation to make the building better'
#  'Much of the components/materials are reusable and recyclable,Much of the wastes can be diverted,Generation of revenues'
#  'Much of the components/materials are reusable and recyclable,Much of the wastes can be diverted'
#  'Much of the wastes can be diverted'
# ...

# %%
columns=[*Raw.columns]
unique_values={}
for i in columns:
    unique_values[i]=Raw[i].unique()
unique=pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in unique_values.items() ]))
unique.fillna('').T
# Out:
#                                                                                    0  \
# Full Participation                                                               yes
# what was done                                                         Deconstruction
# Role                                                       Civil/Structural engineer
# why deconstruct                    Much of the components/materials are reusable ...
# Project Location                                                                  UK
# Building type                                                            Residential
# construction method                                                      Traditional
# Building Age                                                                31-50yrs
# Floors                                                                    1-3 floors
# Rooms                                                                      3-5 rooms
# ...

# %%
percent_missing = Filtered.isnull().sum() * 100 / len(Raw)

# %%
print(percent_missing)
# Out:
# X1      0.000000
# X2     15.306122
# X3     21.428571
# X4     20.408163
# X5     22.448980
# X6     20.408163
# X7     21.428571
# X8     20.408163
# X9     20.408163
# X10    20.408163
# X11    21.428571
# X12    22.448980
# X13    21.428571
# X14    22.448980
# X15    21.428571
# X16    43.877551
# X17    22.448980
# X18    51.020408
# X19    23.469388
# X20    23.469388
# X21    23.469388
# X22    23.469388
# X23    23.469388
# X24    23.469388
# X25    23.469388
# X26    23.469388
# X27    22.448980
# X28    22.448980
# X29    22.448980
# X30    23.469388
# X31    22.448980
# X32    24.489796
# X33    23.469388
# X34    23.469388
# X35    23.469388
# X36    23.469388
# X37    23.469388
# X38    58.163265
# X39    24.489796
# X40    24.489796
# X41    24.489796
# X42    24.489796
# X43    24.489796
# X44    48.979592
# X45    20.408163
# X46    20.408163
# dtype: float64

# %%
#explore the sheet.

from dataprep.eda import create_report
#create_report(Df)

# %%
Code=xl['Code']
Code=Code[['X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14','X15', 'X16', 'X17','X18', 'X19', 'X20', 'X21', 'X22','X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31','X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40','X41', 'X42', 'X43', 'X45']]
Code.head()

# %%
Filter=xl['Filtered']
Filter=Filter.drop(['X1','X44'], axis=1)
Filter.head()

# %%
#code the target feature

Filter['X46']=Filter['X46'].map({'0-20% of the building is/was deconstructible':'1', '81-100% of the building is/was deconstructible':'5',
'61-80% of the building is/was deconstructible':'4',
 '41-60% of the building is/was deconstructible':'3',
 '21-40% of the building is/was deconstructible':'2'})

# %%
#Zero Inputation 
Filter_Replaced=Filter.fillna("0")
Filter_Replaced.head()

# %%
for col in Filter_Replaced:
  print(Filter_Replaced[col].unique())

# %%
#Frequency Encoding

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from feature_engine.encoding import CountFrequencyEncoder
#set up the CountFrequencyEncoder() to replace the categories by their frequencies, 
#only in the indicated variables:

# set up the encoder
encoder = CountFrequencyEncoder(encoding_method='frequency',
                         variables=['X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14',
 'X15', 'X16', 'X17','X18', 'X19', 'X20', 'X21', 'X22','X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40','X41', 'X42', 'X43', 'X45'])

# fit the encoder
encoder.fit(Filter_Replaced)

# %%
#With fit() the encoder learns the frequencies of each category, which are stored in its encoder_dict_ parameter:

encoder.encoder_dict_

# %%
# transform the data
Filter_Replaced_t= encoder.transform(Filter_Replaced)
#test_t= encoder.transform(X_test)

# %%
Filter_Replaced_t.head()

# %%
#train_t.head()

# %%
# Compare Algorithms
#Zero Inputation 
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
#from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score


X = Filter_Replaced_t.drop('X46', axis=1)
y = Filter_Replaced_t['X46']
# Separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)


# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('Multinomial', LogisticRegression(multi_class='multinomial', solver='lbfgs'))) 
models.append(('SVM_Linear', SVC(kernel='linear'))) 
models.append(('SVM_Poly', SVC(kernel='poly'))) 
models.append(('SVM_rbf', SVC(kernel='rbf'))) 
models.append(('SVM_sigmoid', SVC(kernel='sigmoid'))) 
models.append(('GNB', GaussianNB()))
models.append(('XGB', XGBClassifier()))
models.append(('LGBM', lgb.LGBMClassifier()))
models.append(('DT', DecisionTreeClassifier()))


# evaluate each model in turn

results = []
names = []
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
    clf = model.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(name)
    print(classification_report(y_test, y_pred))

# %%
# Mode Imputation
df=Filter
for column in df.columns:
    df[column].fillna(df[column].mode()[0], inplace=True)

# %%
Mode_imputation=df
for col in Mode_imputation:
  print(Mode_imputation[col].unique())

# %%
# set up the encoder
encoder = CountFrequencyEncoder(encoding_method='frequency',
                         variables=['X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14',
 'X15', 'X16', 'X17','X18', 'X19', 'X20', 'X21', 'X22','X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40','X41', 'X42', 'X43', 'X45'])

# fit the encoder
encoder.fit(Mode_imputation)

# transform the data
Mode_imputation_t= encoder.transform(Mode_imputation)
Mode_imputation_t.head()

# %%
# Compare Algorithms
#Zero Inputation 
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
#from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score


X = Mode_imputation_t.drop('X46', axis=1)
y = Mode_imputation_t['X46']
# Separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)


# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('Multinomial', LogisticRegression(multi_class='multinomial', solver='lbfgs'))) 
models.append(('SVM_Linear', SVC(kernel='linear'))) 
models.append(('SVM_Poly', SVC(kernel='poly'))) 
models.append(('SVM_rbf', SVC(kernel='rbf'))) 
models.append(('SVM_sigmoid', SVC(kernel='sigmoid'))) 
models.append(('GNB', GaussianNB()))
models.append(('XGB', XGBClassifier()))
models.append(('LGBM', lgb.LGBMClassifier()))
models.append(('DT', DecisionTreeClassifier()))


# evaluate each model in turn

results = []
names = []
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
    clf = model.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(name)
    print(classification_report(y_test, y_pred))

# %%
import sklearn.neighbors._base
import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %%
#KNN Imputation
# import necessary libraries
import numpy as np
import pandas as pd
  
# import the KNNimputer class
from sklearn.impute import KNNImputer


imputer = KNNImputer()
Knn_impute = imputer.fit_transform(Code)

# %%
print(Knn_impute)

Knn_impute = pd.DataFrame(Knn_impute, columns = ['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','X17','X18','X19','X20','X21','X22','X23','X24','X25','X26','X27','X28','X29','X30','X31','X32','X33','X34','X35','X36','X37','X38','X39','X40','X41','X42','X43','X44'])

# %%
variables=['X1','X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14',
 'X15', 'X16', 'X17','X18', 'X19', 'X20', 'X21', 'X22','X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40','X41', 'X42', 'X43','X44']

for col in variables:
    Knn_impute[col] = Knn_impute[col].astype('category')

# %%
#Frequency Encoding

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from feature_engine.encoding import CountFrequencyEncoder
#set up the CountFrequencyEncoder() to replace the categories by their frequencies, 
#only in the indicated variables:

# set up the encoder
encoder = CountFrequencyEncoder(encoding_method='frequency',
                         variables=['X1','X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14',
 'X15', 'X16', 'X17','X18', 'X19', 'X20', 'X21', 'X22','X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31',
 'X32', 'X33', 'X34', 'X35', 'X36', 'X37', 'X38', 'X39', 'X40','X41', 'X42', 'X43','X44'])

# fit the encoder
encoder.fit(Knn_impute)

# %%
for col in variables:
    Knn_impute[col] = Knn_impute[col].astype('int')

# %%
# Compare Algorithms
#Zero Inputation 
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
#from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score


X = Knn_impute.drop('X44', axis=1)
y = Knn_impute['X44']
# Separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)


# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('Multinomial', LogisticRegression(multi_class='multinomial', solver='lbfgs'))) 
models.append(('SVM_Linear', SVC(kernel='linear'))) 
models.append(('SVM_Poly', SVC(kernel='poly'))) 
models.append(('SVM_rbf', SVC(kernel='rbf'))) 
models.append(('SVM_sigmoid', SVC(kernel='sigmoid'))) 
models.append(('GNB', GaussianNB()))
models.append(('XGB', XGBClassifier()))
models.append(('LGBM', lgb.LGBMClassifier()))
models.append(('DT', DecisionTreeClassifier()))


# evaluate each model in turn

results = []
names = []
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
for name, model in models:
    kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
    clf = model.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(name)
    print(classification_report(y_test, y_pred))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import sklearn.neighbors._base 
import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest
from sklearn.impute import KNNImputer

imputer = MissForest() #miss forest
MF_imputed = imputer.fit_transform(Code)
MF_imputed = pd.DataFrame(X_imputed, columns = ['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','X17','X18','X19','X20','X21','X22','X23','X24','X25','X26','X27','X28','X29','X30','X31','X32','X33','X34','X35','X36','X37','X38','X39','X40','X41','X42','X43','X44'])

# %%
#convert all columns in filtered to labelencode
from sklearn.preprocessing import LabelEncoder
labelled=Filter.apply(LabelEncoder().fit_transform)

# %%
labelled.head()

# %%
labelled.shape

# %%
#write the labelled data to csv
labelled.to_csv('Label.csv')
