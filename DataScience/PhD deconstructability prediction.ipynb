# %% [markdown]
# Building is a where we live and it is where man does all of its activities
#
# Building is an important need of every individual and it constitutes a quite range of activities starting from the idea-design-construction-operation-maintenance and lastly the end of life of the building which is usually after years of use.

# %% [markdown]
# This notebook contain the codes on the Building Deconstructability Prediction using Artificial intelligence Model
#
# Written and implemented by h.balogun@herts.ac.uk  \\ www.linkedin.com/in/habeebbalogun

# %%
#import all packages useful for the analysis
import pandas as pd #import pandas method to get the data
import matplotlib.pyplot as plt

# %%
#check the working directory to be sure we are in the path where the data is located, for this we have to be in downloads
#cd/users/habeeb/Downloads
# !pwd
# Out:
# /Users/habeeb/Downloads/PhD Analysis

# %%
data=pd.read_excel('PhD Data.xlsx',header=None, skiprows=[0],engine='openpyxl')

# %%
data.head() #view the header of the data
# Out:
#     0               1                          2   \
# 0  yes  Deconstruction  Civil/Structural engineer
# 1  yes      Renovation                 Supervisor
# 2  yes  Deconstruction       construction manager
# 3   no             NaN                        NaN
# 4   no             NaN                        NaN
#
#                                                   3        4              5   \
# 0  Much of the components/materials are reusable ...       UK    Residential
# 1  Much of the components/materials are reusable ...  Nigeria    Residential
# 2  Much of the components/materials are reusable ...  Nigeria  Institutional
# 3                                                NaN      NaN            NaN
# 4                                                NaN      NaN            NaN
#
#             6            7           8          9   ...            36  \
# 0  Traditional     31-50yrs  1-3 floors  3-5 rooms  ...      Disagree
# ...

# %%
#investigate the end of life options mostly done by the respondents in the past
data[1].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#investigate the professions of the respondents
data[2].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#investigate other professions not stated
data[3].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#investigate the reasons for deconstruction by experts
data[4].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#investigate the reasons for deconstruction by experts
data[5].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(data[6],data[1]).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='6'>

# %%
pd.crosstab(data[7],data[1]).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='7'>

# %%
pd.crosstab(data[1],data[2]).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='1'>

# %%
#investigate the end of life options mostly done by the respondents in the past
data[8].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(data[1],data[8]).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='1'>

# %% [markdown]
# ### Process the data
#
# As observed from the data, most features with object types are categorical and needs to be preprocessed before using machine learning on them.
#
# what is categorical feature? Categorical data is non-numeric and often can be characterized into categories or groups. A simple example is the option at the EOL;renovation, deconstrcution or demolition. Another example is the  interval-type data. Like 2-5days, 6-10days etc., and so on. The intervals are categorical.
#
# - why Encode categorical data?
# - We encode categorical data numerically because math is generally done using numbers. A big part of natural language processing is converting text to numbers. Just like that, our algorithms cannot run and process data if that data is not numerical.
#
# - Therefore, we need to have tools at our disposal to transform colors like red, yellow, and blue into numbers like 1, 2, and 3 for all the backend math to take place. Now that we know what categorical data looks like and have seen some examples, we will examine three common methods to turn our categorical data into numeric data.
#
# The convertion of the categorical data to numeric can be done using
# - one hot, label and target encoder.
#
# - we will be using label encoder

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 46 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       98 non-null     object
#  1   1       47 non-null     object
#  2   2       41 non-null     object
#  3   3       42 non-null     object
#  4   4       41 non-null     object
#  5   5       42 non-null     object
#  6   6       41 non-null     object
#  7   7       42 non-null     object
#  8   8       42 non-null     object
#  9   9       42 non-null     object
#  10  10      42 non-null     object
#  11  11      40 non-null     object
#  12  12      42 non-null     object
#  13  13      42 non-null     object
#  14  14      41 non-null     object
#  15  15      41 non-null     object
#  16  16      41 non-null     object
#  17  17      19 non-null     object
#  18  18      40 non-null     object
#  19  19      12 non-null     object
#  20  20      39 non-null     object
# ...
